# %%
import pandas as pd

# %%
community_df = pd.read_excel('../data-dir/kakao-community-preprocessed.xlsx')
stock_df = pd.read_excel('../data-dir/kakao-stock-preprocessed.xlsx')
total_df = stock_df.set_index('DayIndex')

# %%
total_df
# Out:
#                    Open      High       Low     Close
# DayIndex
# 2022-10-13_AM  0.748025  0.748025  0.705613  0.715593
# 2022-10-13_PM  0.714761  0.718919  0.705613  0.645738
# 2022-10-14_AM  0.734719  0.772141  0.734719  0.765489
# 2022-10-14_PM  0.767152  0.775468  0.763825  0.773805
# 2022-10-17_AM  0.773805  0.773805  0.693139  0.729730
# ...                 ...       ...       ...       ...
# 2023-01-12_PM  0.946778  0.950104  0.941788  0.941788
# 2023-01-13_AM  0.951767  0.966736  0.941788  0.951767
# 2023-01-13_PM  0.951767  0.955094  0.946778  0.951767
# 2023-01-16_AM  0.950104  1.000000  0.950104  0.988358
# 2023-01-16_PM  0.990021  0.996674  0.983368  0.991684
#
# [132 rows x 4 columns]

# %% [markdown]
# ## Aggregation

# %%
community_df = community_df.drop('Unnamed: 0', axis=1)

# %%
total_df['CommunityText'] = community_df.groupby('DayIndex')['CommunityText'].apply(list)
total_df['MetricIndex'] = community_df.groupby('DayIndex')['MetricIndex'].apply(list)

# %%
len(total_df)
# Out:
# 132

# %%
total_df = total_df.dropna(axis=0)

# %%
total_df.isna().sum()
# Out:
# Open             0
# High             0
# Low              0
# Close            0
# CommunityText    0
# MetricIndex      0
# dtype: int64

# %%
total_df
# Out:
#                    Open      High       Low     Close  \
# DayIndex
# 2022-10-14_AM  0.734719  0.772141  0.734719  0.765489
# 2022-10-14_PM  0.767152  0.775468  0.763825  0.773805
# 2022-10-17_AM  0.773805  0.773805  0.693139  0.729730
# 2022-10-20_AM  0.747193  0.747193  0.708940  0.708940
# 2022-10-20_PM  0.708940  0.718087  0.705613  0.713098
# ...                 ...       ...       ...       ...
# 2023-01-04_PM  0.833680  0.850312  0.833680  0.845322
# 2023-01-05_AM  0.845322  0.881913  0.845322  0.876923
# 2023-01-05_PM  0.876923  0.886902  0.873597  0.878586
# 2023-01-06_AM  0.878586  0.883576  0.861954  0.873597
# 2023-01-06_PM  0.873597  0.876923  0.860291  0.870270
#
#                                                    CommunityText  \
# DayIndex
# 2022-10-14_AM  [씨없는 카카오?알맹이가 없어 껍데기뿐인 카카오를 어디다 쓰나?강방천씨 나좀 이해좀...
# 2022-10-14_PM  [다음주에 엄청 빠지겠네..., 51000~51300원 사이에서80%매도 기다린다 ...
# 2022-10-17_AM  [카카오관련주 모두 지난 금요일 대량거래후유증 크겠다.n추가상승 노리고  매수후 보...
# 2022-10-20_AM  [신뢰도가 추락한만큼이미지 쇄신을 위해서 분할상장 앞으로 없다고 하고 지금이라도 자...
# 2022-10-20_PM  [진바닥 알려줄게 이만오처넌이야딱 갈치 고등어 반토막 ㅋㅋ, 오늘도 개미는 열심히 ...
# ...                                                          ...
# 2023-01-04_PM  [어차피 내일 조정 나올건데 1천원만 더 올라가면 안되겠니?제발욤 ㅎㅎ, 외국인 기...
# 2023-01-05_AM  [속보  사우디펀드카카오엔터 1조투자이거이거~~~지분73%있는거는 알재?, 오늘오늘...
# 2023-01-05_PM  [인문학사회분야헤게모니들에게...기득권파쇼들에게 ..그저 ""전술로 이용되기나하는것...
# 2023-01-06_AM  [2023년 올해들어서 1월1일 나는 아래와같은 금융댓글 30일사용정지를 받았습니다...
# 2023-01-06_PM  [참 공매도 찌질이들...거래량도 얼마 없이 멈추니 장난질하네 ...참 ...찌질이...
#
#                                                      MetricIndex
# DayIndex
# 2022-10-14_AM  [0.0, 0.0, 0.005847953216374269, 0.00546448087...
# 2022-10-14_PM  [-0.003012048192771084, -0.005025125628140704,...
# 2022-10-17_AM  [0.007407407407407408, 0.008695652173913044, 0...
# 2022-10-20_AM  [0.05333333333333334, 0.02678571428571428, 0.0...
# 2022-10-20_PM  [0.0, 0.007692307692307693, 0.0, 0.00719424460...
# ...                                                          ...
# 2023-01-04_PM  [0.0, -0.008888888888888889, 0.0, 0.0021645021...
# 2023-01-05_AM  [0.005607476635514018, 0.0, 0.0026109660574412...
# 2023-01-05_PM  [-0.005747126436781609, -0.004975124378109453,...
# 2023-01-06_AM  [0.0, -0.003773584905660377, 0.0, 0.0059880239...
# 2023-01-06_PM  [0.0, 0.003584229390681004, -0.008771929824561...
#
# [113 rows x 6 columns]

# %%
total_df[total_df['CommunityText'].isna()].count()
# Out:
# Open             0
# High             0
# Low              0
# Close            0
# CommunityText    0
# MetricIndex      0
# dtype: int64

# %%
total_df = total_df.dropna(axis=0).reset_index()
total_df.head()
# Out:
#         DayIndex      Open      High       Low     Close  \
# 0  2022-10-14_AM  0.734719  0.772141  0.734719  0.765489
# 1  2022-10-14_PM  0.767152  0.775468  0.763825  0.773805
# 2  2022-10-17_AM  0.773805  0.773805  0.693139  0.729730
# 3  2022-10-20_AM  0.747193  0.747193  0.708940  0.708940
# 4  2022-10-20_PM  0.708940  0.718087  0.705613  0.713098
#
#                                        CommunityText  \
# 0  [씨없는 카카오?알맹이가 없어 껍데기뿐인 카카오를 어디다 쓰나?강방천씨 나좀 이해좀...
# 1  [다음주에 엄청 빠지겠네..., 51000~51300원 사이에서80%매도 기다린다 ...
# 2  [카카오관련주 모두 지난 금요일 대량거래후유증 크겠다.n추가상승 노리고  매수후 보...
# 3  [신뢰도가 추락한만큼이미지 쇄신을 위해서 분할상장 앞으로 없다고 하고 지금이라도 자...
# 4  [진바닥 알려줄게 이만오처넌이야딱 갈치 고등어 반토막 ㅋㅋ, 오늘도 개미는 열심히 ...
#
#                                          MetricIndex
# 0  [0.0, 0.0, 0.005847953216374269, 0.00546448087...
# 1  [-0.003012048192771084, -0.005025125628140704,...
# 2  [0.007407407407407408, 0.008695652173913044, 0...
# 3  [0.05333333333333334, 0.02678571428571428, 0.0...
# 4  [0.0, 0.007692307692307693, 0.0, 0.00719424460...

# %% [markdown]
# ## Labeling

# %%
mean = total_df[['Open', 'Close', 'High', 'Low']].mean(axis=1)
mean = mean.shift(1)
mean.loc[0] = 0
mean
# Out:
# 0      0.000000
# 1      0.751767
# 2      0.770062
# 3      0.742620
# 4      0.728067
#          ...
# 108    0.819958
# 109    0.840748
# 110    0.862370
# 111    0.879002
# 112    0.874428
# Length: 113, dtype: float64

# %%
index = total_df['Close'] < mean
total_df['Label'] = 0
total_df.loc[index, 'Label'] = 1

total_df
# Out:
#           DayIndex      Open      High       Low     Close  \
# 0    2022-10-14_AM  0.734719  0.772141  0.734719  0.765489
# 1    2022-10-14_PM  0.767152  0.775468  0.763825  0.773805
# 2    2022-10-17_AM  0.773805  0.773805  0.693139  0.729730
# 3    2022-10-20_AM  0.747193  0.747193  0.708940  0.708940
# 4    2022-10-20_PM  0.708940  0.718087  0.705613  0.713098
# ..             ...       ...       ...       ...       ...
# 108  2023-01-04_PM  0.833680  0.850312  0.833680  0.845322
# 109  2023-01-05_AM  0.845322  0.881913  0.845322  0.876923
# 110  2023-01-05_PM  0.876923  0.886902  0.873597  0.878586
# 111  2023-01-06_AM  0.878586  0.883576  0.861954  0.873597
# 112  2023-01-06_PM  0.873597  0.876923  0.860291  0.870270
#
#                                          CommunityText  \
# 0    [씨없는 카카오?알맹이가 없어 껍데기뿐인 카카오를 어디다 쓰나?강방천씨 나좀 이해좀...
# 1    [다음주에 엄청 빠지겠네..., 51000~51300원 사이에서80%매도 기다린다 ...
# 2    [카카오관련주 모두 지난 금요일 대량거래후유증 크겠다.n추가상승 노리고  매수후 보...
# 3    [신뢰도가 추락한만큼이미지 쇄신을 위해서 분할상장 앞으로 없다고 하고 지금이라도 자...
# 4    [진바닥 알려줄게 이만오처넌이야딱 갈치 고등어 반토막 ㅋㅋ, 오늘도 개미는 열심히 ...
# ..                                                 ...
# 108  [어차피 내일 조정 나올건데 1천원만 더 올라가면 안되겠니?제발욤 ㅎㅎ, 외국인 기...
# 109  [속보  사우디펀드카카오엔터 1조투자이거이거~~~지분73%있는거는 알재?, 오늘오늘...
# 110  [인문학사회분야헤게모니들에게...기득권파쇼들에게 ..그저 ""전술로 이용되기나하는것...
# 111  [2023년 올해들어서 1월1일 나는 아래와같은 금융댓글 30일사용정지를 받았습니다...
# 112  [참 공매도 찌질이들...거래량도 얼마 없이 멈추니 장난질하네 ...참 ...찌질이...
#
#                                            MetricIndex  Label
# 0    [0.0, 0.0, 0.005847953216374269, 0.00546448087...      0
# 1    [-0.003012048192771084, -0.005025125628140704,...      0
# 2    [0.007407407407407408, 0.008695652173913044, 0...      1
# 3    [0.05333333333333334, 0.02678571428571428, 0.0...      1
# 4    [0.0, 0.007692307692307693, 0.0, 0.00719424460...      1
# ..                                                 ...    ...
# 108  [0.0, -0.008888888888888889, 0.0, 0.0021645021...      0
# 109  [0.005607476635514018, 0.0, 0.0026109660574412...      0
# 110  [-0.005747126436781609, -0.004975124378109453,...      0
# 111  [0.0, -0.003773584905660377, 0.0, 0.0059880239...      1
# 112  [0.0, 0.003584229390681004, -0.008771929824561...      1
#
# [113 rows x 8 columns]

# %%
total_df.to_pickle('../data-dir/data-df.pkl')
